# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from twitch import TwitchClient

# %% [markdown]
# #### Twitch Client Setup

# %%
# creating Twitch Client
client = TwitchClient(client_id = "zjwe67emf2ri3ecyqvihgzhb1r3l4i")

# %%
# get user ID from username
# adapted from Twitchly source code
from requests.exceptions import HTTPError
def get_user_id(user_name: str):
    msg = user_name
    try:
        users = client.users.translate_usernames_to_ids([user_name])
        id_ = users[0].id
        # print(msg)
        return id_
    except HTTPError:
        print(msg, 'HTTP')
        return None
    except IndexError:
        print(msg, 'INDEX')
        return None

# %%
# get channel ID from username (should be the same)
def get_channel_id(user_name: str):
    return get_user_id(user_name)

# get k followers for a particular channel
def get_all_followers_by_channel_id(channel_id: str, max_followers: int, print_progress=False):
    
    limit = 100 # scroll limit
    
    followers = [] 
    offset = 0
    current_scroll = client.channels.get_followers(channel_id, limit, offset)
    while current_scroll and len(followers) < max_followers:
        for follower in current_scroll:
            offset += 1
            user = follower.user.id
            name = follower.user.name
            followers.append(user)
        try:
            current_scroll = client.channels.get_followers(channel_id, limit, offset)
            if print_progress:
                print('Progress:', offset)
        except HTTPError:
            print('HTTP')
            return followers
    return followers

# %%
# get all followers from username (?)
def get_followers_by_user_name(user_name: str, max_followers=50000):
    return get_all_followers_by_channel_id(get_channel_id(user_name), max_followers)

# %% [markdown]
# #### Load StreamersList dataframe

# %%
# load top user data
streamers = pd.read_csv('StreamersList.csv')
streamers.head()
# Out:
#        Streamer      Game
# 0         Ninja  Fortnite
# 1          Tfue  Fortnite
# 2       dakotaz  Fortnite
# 3  TimTheTatman  Fortnite
# 4     NICKMERCS  Fortnite

# %%
streamers['User ID'] = streamers['Streamer'].map(get_user_id)
# Out:
# Riot Games HTTP
# OrgamingLol INDEX
# nacrutkahmm INDEX
# streamhubus INDEX
# mayannagirl INDEX

# %%
streamers.head()
# Out:
#        Streamer      Game   User ID
# 0         Ninja  Fortnite  19571641
# 1          Tfue  Fortnite  60056333
# 2       dakotaz  Fortnite  39298218
# 3  TimTheTatman  Fortnite  36769016
# 4     NICKMERCS  Fortnite  15564828

# %%
# Testing on Ninja
followers = [get_followers_by_user_name('Ninja', max_followers=50000)]
# Out:
# Progress: 100
# Progress: 200
# Progress: 300
# Progress: 400
# Progress: 500
# Progress: 600
# Progress: 700
# Progress: 800
# Progress: 900
# Progress: 1000
# Progress: 1100
# Progress: 1200
# Progress: 1300
# Progress: 1400
# Progress: 1500
# Progress: 1600
# HTTP

# %%
len(followers)
# Out:
# 1

# %%
followers
# Out:
# [['224506553',
#   '247118157',
#   '267806694',
#   '268331298',
#   '252422854',
#   '237285031',
#   '237610949',
#   '268331340',
#   '268331202',
#   '268196602',
#   '257828011',
#   '215081060',
#   '127324718',
#   '254268633',
#   '264712714',
#   '154747283',
#   '268331284',
#   '265375913',
#   '268331265',
#   '268045844',
#   '236806345',
#   '268331321',
#   '266196771',
#   '191339288',
#   '268158185',
#   '268079912',
#   '259266203',
#   '230889447',
#   '245230300',
#   '177626930',
#   '268329655',
#   '267631511',
#   '251235793',
#   '246831078',
#   '268177572',
#   '268331544',
#   '185740836',
#   '267141132',
#   '264843555',
#   '268331190',
#   '242149709',
#   '253999128',
#   '268330334',
#   '258552680',
#   '144778117',
#   '229176228',
#   '268331310',
#   '94700465',
#   '267817394',
#   '268330790',
#   '254603566',
#   '268315488',
#   '268331426',
#   '254124111',
#   '268327857',
#   '268331217',
#   '268234221',
#   '268330585',
#   '268330801',
#   '266343605',
#   '80215246',
#   '268145240',
#   '268163578',
#   '262925076',
#   '268330805',
#   '268330300',
#   '195737850',
#   '266535450',
#   '268129450',
#   '266099800',
#   '262121180',
#   '260711721',
#   '268330991',
#   '257890814',
#   '98434410',
#   '268311460',
#   '268166212',
#   '194727975',
#   '162325417',
#   '264334289',
#   '263214492',
#   '268329797',
#   '241379205',
#   '201733412',
#   '268195629',
#   '267687839',
#   '268136095',
#   '143131653',
#   '268280390',
#   '265356799',
#   '268271462',
#   '210224055',
#   '215092398',
#   '219583205',
#   '258928673',
#   '193360701',
#   '138664096',
#   '268330663',
#   '267789546',
#   '268065840',
#   '267789546',
#   '268065840',
#   '268330392',
#   '85349708',
#   '268326111',
#   '266644850',
#   '267941795',
#   '268330217',
#   '268330293',
#   '268328768',
#   '268331059',
#   '228011483',
#   '260564958',
#   '210449465',
#   '267891038',
#   '175071766',
#   '260103829',
#   '268330435',
#   '268322856',
#   '257388661',
#   '268330762',
#   '196247219',
#   '190705163',
#   '252287425',
#   '213887162',
#   '230243971',
#   '261805273',
#   '268120217',
#   '239860972',
#   '268330513',
#   '267669676',
#   '268330682',
#   '268329979',
#   '186205907',
#   '267865986',
#   '265325464',
#   '204224697',
#   '92877769',
#   '233440673',
#   '172243614',
#   '268289156',
#   '262631559',
#   '268330970',
#   '259246617',
#   '143564179',
#   '241438712',
#   '256682273',
#   '268330099',
#   '246528404',
#   '158285784',
#   '267779539',
#   '261506818',
#   '215152460',
#   '217817522',
#   '268330692',
#   '268329614',
#   '268330224',
#   '184911941',
#   '153837391',
#   '266505400',
#   '268330559',
#   '268329978',
#   '268320449',
#   '268330274',
#   '268330005',
#   '192943226',
#   '268330530',
#   '153212272',
#   '268330287',
#   '268262279',
#   '258930655',
#   '207385412',
#   '268330131',
#   '67495298',
#   '152892645',
#   '227937464',
#   '267564633',
#   '265011346',
#   '267084290',
#   '197657893',
#   '268330500',
#   '210619388',
#   '133546176',
#   '267939211',
#   '248138870',
#   '267930291',
#   '259939859',
#   '268330466',
#   '243532484',
#   '267542264',
#   '203569500',
#   '268330391',
#   '234090839',
#   '268329303',
#   '152669992',
#   '268329107',
#   '220974529',
#   '257103736',
#   '268317218',
#   '268077643',
#   '267405717',
#   '248312231',
#   '268330457',
#   '251117301',
#   '266187314',
#   '268202513',
#   '254075805',
#   '268330063',
#   '267567725',
#   '155011600',
#   '268106404',
#   '224965131',
#   '267925577',
#   '268330115',
#   '206540747',
#   '268329699',
#   '267346783',
#   '209252468',
#   '238360020',
#   '229341804',
#   '268327239',
#   '142372915',
#   '263896708',
#   '213113417',
#   '190320054',
#   '268297152',
#   '248719746',
#   '268327873',
#   '268329452',
#   '268103801',
#   '268329457',
#   '184078369',
#   '268329951',
#   '161438424',
#   '260800959',
#   '267134966',
#   '220998245',
#   '268216468',
#   '268330121',
#   '268330336',
#   '259929188',
#   '255253370',
#   '268329894',
#   '268330070',
#   '89587979',
#   '257251106',
#   '224510833',
#   '268329583',
#   '210888271',
#   '268329598',
#   '268298880',
#   '241908819',
#   '252337722',
#   '197736653',
#   '268329435',
#   '268132517',
#   '268325595',
#   '228628909',
#   '261464109',
#   '233442968',
#   '72336761',
#   '268075282',
#   '251425293',
#   '180160871',
#   '268234209',
#   '268329626',
#   '202126009',
#   '267370492',
#   '268200530',
#   '233003636',
#   '268328689',
#   '268328676',
#   '268330051',
#   '250154896',
#   '218660691',
#   '267671772',
#   '146707085',
#   '268304780',
#   '32098413',
#   '268312864',
#   '266977559',
#   '170224675',
#   '262719367',
#   '268329234',
#   '263798679',
#   '268079645',
#   '237111997',
#   '256979311',
#   '268329406',
#   '251490817',
#   '268326626',
#   '268321855',
#   '76064308',
#   '256001383',
#   '120268714',
#   '268328857',
#   '178504645',
#   '228110607',
#   '268329310',
#   '268328748',
#   '213024161',
#   '268328678',
#   '123839992',
#   '163811852',
#   '83201699',
#   '268329682',
#   '266733414',
#   '76213578',
#   '268328104',
#   '268329154',
#   '264507239',
#   '268329370',
#   '259493612',
#   '267595487',
#   '235965802',
#   '208282155',
#   '268329857',
#   '267867464',
#   '268326954',
#   '268152560',
#   '268037704',
#   '93147201',
#   '268320892',
#   '123784608',
#   '268327774',
#   '268329584',
#   '268234625',
#   '213156429',
#   '245276278',
#   '212706427',
#   '266800064',
#   '199427323',
#   '252719645',
#   '268328974',
#   '263777671',
#   '223069890',
#   '252772800',
#   '116616962',
#   '83198770',
#   '268329035',
#   '268329255',
#   '117308679',
#   '265536894',
#   '240754892',
#   '265019163',
#   '115724316',
#   '160715929',
#   '252619503',
#   '266852912',
#   '253164781',
#   '185356992',
#   '259732538',
#   '219316458',
#   '248331385',
#   '263422615',
#   '227543460',
#   '267304193',
#   '268094488',
#   '229158340',
#   '253274421',
#   '266392898',
#   '251804133',
#   '212133650',
#   '266971911',
#   '212017187',
#   '265269698',
#   '268329673',
#   '69923415',
#   '247325259',
#   '261695877',
#   '167099369',
#   '263636468',
#   '265909713',
#   '37698411',
#   '268329287',
#   '268090875',
#   '222615402',
#   '264932281',
#   '268239422',
#   '176482729',
#   '103808657',
#   '240857619',
#   '220291804',
#   '220938383',
#   '196668891',
#   '268328874',
#   '268328892',
#   '221520133',
#   '268329190',
#   '254242593',
#   '229580470',
#   '268329269',
#   '211343412',
#   '266263577',
#   '268329476',
#   '142096437',
#   '264316979',
#   '267337908',
#   '268326976',
#   '268328911',
#   '152616660',
#   '266339283',
#   '203905677',
#   '268328229',
#   '256460139',
#   '267922780',
#   '267970156',
#   '232376703',
#   '268329481',
#   '168164073',
#   '125716574',
#   '252694035',
#   '268329064',
#   '267894014',
#   '245721228',
#   '158779624',
#   '263325250',
#   '268327456',
#   '268329111',
#   '101695716',
#   '185211071',
#   '257349564',
#   '267935597',
#   '267411413',
#   '254042811',
#   '232160414',
#   '264067772',
#   '91702989',
#   '266037545',
#   '258148808',
#   '250385103',
#   '268147212',
#   '268327780',
#   '268329171',
#   '260594643',
#   '268328542',
#   '268157107',
#   '258894472',
#   '268327261',
#   '211117896',
#   '235996905',
#   '236314467',
#   '268042530',
#   '186150696',
#   '268328862',
#   '258468037',
#   '238505344',
#   '266783700',
#   '268328918',
#   '268328741',
#   '265417531',
#   '266674883',
#   '267666558',
#   '242018136',
#   '268328784',
#   '131109916',
#   '162085250',
#   '259229613',
#   '267411477',
#   '268323009',
#   '257213453',
#   '268328694',
#   '258564334',
#   '140620305',
#   '262957720',
#   '263063898',
#   '266591141',
#   '268328183',
#   '235620136',
#   '268328553',
#   '237899252',
#   '210312936',
#   '268321511',
#   '268328145',
#   '266140646',
#   '130545107',
#   '210935092',
#   '261107729',
#   '268329121',
#   '266787155',
#   '268329063',
#   '268250997',
#   '267172134',
#   '256119863',
#   '244063364',
#   '257203569',
#   '207880835',
#   '226174399',
#   '61903487',
#   '267882440',
#   '268328515',
#   '240433518',
#   '254500836',
#   '268328179',
#   '266315079',
#   '257173039',
#   '257272153',
#   '268327474',
#   '266834018',
#   '146556077',
#   '259307079',
#   '268303037',
#   '233867706',
#   '258470876',
#   '227380116',
#   '268328491',
#   '219729133',
#   '227291434',
#   '228226719',
#   '238980394',
#   '105439734',
#   '241298452',
#   '261724360',
#   '258573949',
#   '268328680',
#   '143930417',
#   '268141353',
#   '127903882',
#   '259429226',
#   '254217369',
#   '85950016',
#   '254033551',
#   '241375361',
#   '268005193',
#   '263340573',
#   '202157125',
#   '154646806',
#   '122420357',
#   '218307504',
#   '268325672',
#   '267810619',
#   '195356951',
#   '266361228',
#   '267384742',
#   '243656438',
#   '70747752',
#   '256142397',
#   '244602055',
#   '195828235',
#   '52667610',
#   '234071784',
#   '250809146',
#   '268009340',
#   '268318342',
#   '241703176',
#   '168935387',
#   '114537677',
#   '257233760',
#   '256645372',
#   '190660080',
#   '191992281',
#   '266758091',
#   '266632348',
#   '268328434',
#   '267392963',
#   '261800198',
#   '247588041',
#   '268237873',
#   '268328077',
#   '267838939',
#   '161708117',
#   '267996487',
#   '268295755',
#   '257806188',
#   '268328368',
#   '266581596',
#   '268221216',
#   '263296576',
#   '268327061',
#   '268326155',
#   '255609587',
#   '246157208',
#   '267875038',
#   '244010177',
#   '252808920',
#   '268293179',
#   '268303399',
#   '230913560',
#   '157284744',
#   '268322362',
#   '265691277',
#   '253839282',
#   '268327262',
#   '191492687',
#   '268328519',
#   '38227763',
#   '268321540',
#   '256825984',
#   '122650384',
#   '249605953',
#   '166918083',
#   '145446129',
#   '268327498',
#   '149789186',
#   '262970004',
#   '267925632',
#   '235475044',
#   '254686137',
#   '268185785',
#   '268328413',
#   '165285398',
#   '216702913',
#   '258989672',
#   '267870525',
#   '258249254',
#   '181229387',
#   '257891061',
#   '218515763',
#   '266149409',
#   '30338341',
#   '257199037',
#   '190743256',
#   '268295820',
#   '258569093',
#   '268328452',
#   '237734924',
#   '266813653',
#   '248017958',
#   '265801417',
#   '258525032',
#   '196621587',
#   '268325728',
#   '267827082',
#   '7234002',
#   '268328141',
#   '265259538',
#   '268328044',
#   '268287326',
#   '259312775',
#   '266489884',
#   '268282346',
#   '268327677',
#   '245853685',
#   '38954797',
#   '257140077',
#   '259151226',
#   '261570156',
#   '267398708',
#   '193355109',
#   '222533088',
#   '267178555',
#   '262015132',
#   '262314829',
#   '201819398',
#   '268325792',
#   '268093809',
#   '267635085',
#   '268201581',
#   '268294255',
#   '190870761',
#   '179221127',
#   '268323197',
#   '239692972',
#   '203507589',
#   '248886799',
#   '263571893',
#   '60097089',
#   '268327550',
#   '265458470',
#   '31912357',
#   '268315739',
#   '268326706',
#   '268219111',
#   '262013390',
#   '211248588',
#   '136571982',
#   '189415433',
#   '211765003',
#   '268110021',
#   '163786167',
#   '175365922',
#   '266176569',
#   '232651325',
#   '250540032',
#   '211407338',
#   '267996775',
#   '268327686',
#   '268325909',
#   '190945767',
#   '185143120',
#   '62784765',
#   '167920176',
#   '248481758',
#   '127444064',
#   '162831707',
#   '237433618',
#   '266543566',
#   '193710662',
#   '264149407',
#   '160786554',
#   '241669114',
#   '268327963',
#   '216306428',
#   '268323321',
#   '268326327',
#   '265632284',
#   '259526220',
#   '213348778',
#   '268005210',
#   '265975786',
#   '268315746',
#   '204336218',
#   '195288365',
#   '237661751',
#   '268327778',
#   '268326972',
#   '266520490',
#   '267784797',
#   '267244845',
#   '232896517',
#   '241634384',
#   '220822431',
#   '133440069',
#   '268328054',
#   '268327854',
#   '268321225',
#   '261814177',
#   '265004465',
#   '268328160',
#   '268195925',
#   '172135841',
#   '249734946',
#   '85968628',
#   '268328078',
#   '268327708',
#   '262864311',
#   '92431813',
#   '268327088',
#   '259563053',
#   '268171507',
#   '267881720',
#   '268325782',
#   '220473847',
#   '268327829',
#   '227515598',
#   '267030699',
#   '266836641',
#   '245805225',
#   '268327465',
#   '268089987',
#   '258383596',
#   '249219168',
#   '219144738',
#   '253934148',
#   '265304428',
#   '230065892',
#   '268174465',
#   '161780509',
#   '268322716',
#   '268325414',
#   '254754832',
#   '224783161',
#   '268307571',
#   '196921261',
#   '260341071',
#   '268326199',
#   '207364807',
#   '268327490',
#   '230054176',
#   '267254601',
#   '268327155',
#   '265940782',
#   '201898850',
#   '265027024',
#   '268327744',
#   '52040935',
#   '156557006',
#   '266524608',
#   '268327645',
#   '267149272',
#   '267096724',
#   '265910630',
#   '266042858',
#   '246144223',
#   '221071686',
#   '239886198',
#   '268310579',
#   '267848883',
#   '268316384',
#   '268327324',
#   '268326857',
#   '258233025',
#   '268327558',
#   '268327164',
#   '268325602',
#   '268327119',
#   '267619744',
#   '268326798',
#   '234991531',
#   '68692871',
#   '123619831',
#   '267508715',
#   '266215782',
#   '249831287',
#   '48208430',
#   '202588922',
#   '268326870',
#   '261587300',
#   '233597869',
#   '208160915',
#   '266062614',
#   '268327020',
#   '170681376',
#   '268300759',
#   '46088519',
#   '201651643',
#   '267747697',
#   '249921665',
#   '263514074',
#   '265940427',
#   '268326052',
#   '267959070',
#   '252002768',
#   '268320088',
#   '259002958',
#   '252452777',
#   '175275778',
#   '264841324',
#   '253830689',
#   '256523089',
#   '258861593',
#   '265339669',
#   '178912100',
#   '252851913',
#   '240905924',
#   '268327468',
#   '233710804',
#   '242244286',
#   '223912398',
#   '246803932',
#   '268320406',
#   '237776466',
#   '268322875',
#   '268326569',
#   '268321546',
#   '267787927',
#   '257540690',
#   '230500330',
#   '268326179',
#   '268321834',
#   '267998830',
#   '268077906',
#   '141567911',
#   '241106494',
#   '259854101',
#   '268326201',
#   '258780527',
#   '268326178',
#   '211163786',
#   '264208844',
#   '228218832',
#   '130386447',
#   '224200688',
#   '138309419',
#   '268322877',
#   '120038246',
#   '245946166',
#   '268326939',
#   '63854742',
#   '268326335',
#   '212282564',
#   '235551194',
#   '268318457',
#   '267333442',
#   '268308998',
#   '240411423',
#   '100299026',
#   '268164378',
#   '247491967',
#   '256666218',
#   '223011927',
#   '221759120',
#   '250468257',
#   '157950844',
#   '268326738',
#   '264028257',
#   '268326602',
#   '250044344',
#   '199499308',
#   '268326100',
#   '268327043',
#   '218957447',
#   '262215001',
#   '268272440',
#   '206786569',
#   '259377065',
#   '268325773',
#   '268325548',
#   '245592965',
#   '253565116',
#   '238205330',
#   '261732460',
#   '267597872',
#   '268326641',
#   '237752532',
#   '249955847',
#   '257122655',
#   '268233726',
#   '217943426',
#   '27477835',
#   '258152095',
#   '213726249',
#   '202889409',
#   '268048303',
#   '254912355',
#   '268326354',
#   '244966888',
#   '265539678',
#   '268174811',
#   '268326667',
#   '213038273',
#   '182481486',
#   '267336776',
#   '268160949',
#   '255539270',
#   '60478708',
#   '267881541',
#   '38365673',
#   '196449285',
#   '266390534',
#   '227299686',
#   '268327037',
#   '268326668',
#   '260504221',
#   '211522658',
#   '223837158',
#   '268324926',
#   '141661546',
#   '263450034',
#   '262468879',
#   '268250575',
#   '268326208',
#   '268309941',
#   '268323891',
#   '266374212',
#   '248579459',
#   '268151808',
#   '268325952',
#   '268301886',
#   '267946665',
#   '244650041',
#   '185210374',
#   '256268776',
#   '206498806',
#   '159862297',
#   '247622824',
#   '235738564',
#   '268218012',
#   '268326550',
#   '266769438',
#   '268326474',
#   '148141120',
#   '268326618',
#   '268325496',
#   '231540691',
#   '267160359',
#   '268326202',
#   '243901028',
#   '268208258',
#   '256152553',
#   '268025668',
#   '263622311',
#   '136063592',
#   '268326536',
#   '225761800',
#   '248579644',
#   '223336602',
#   '265650158',
#   '268270941',
#   '268271355',
#   '262745728',
#   '263037974',
#   '268320085',
#   '268325657',
#   '251246271',
#   '146108803',
#   '262558613',
#   '266661262',
#   '193324506',
#   '211341789',
#   '268326376',
#   '267821454',
#   '264547082',
#   '268325243',
#   '161196587',
#   '228088984',
#   '263475690',
#   '220393183',
#   '251671520',
#   '268325800',
#   '268325680',
#   '258903067',
#   '268147271',
#   '183722027',
#   '175816376',
#   '255592596',
#   '268326032',
#   '212427507',
#   '266384404',
#   '255131824',
#   ...]]

# %% [markdown]
# #### Notes
# - code above seems to work, channel id and user id might be interchangeable
# - results in an HTTPError after offset 1700 (maybe we can only pull top 1700 followers?)

# %%
streamers['Followers Sample'] = streamers['User ID'].map(lambda x: get_all_followers_by_channel_id(x, 200) if x else None)

# %%
len(followers)
# Out:
# 100

# %%
streamers.head()
# Out:
#        Streamer      Game   User ID  \
# 0         Ninja  Fortnite  19571641
# 1          Tfue  Fortnite  60056333
# 2       dakotaz  Fortnite  39298218
# 3  TimTheTatman  Fortnite  36769016
# 4     NICKMERCS  Fortnite  15564828
#
#                                     Followers Sample
# 0  [268234051, 81724021, 245071158, 268333378, 26...
# 1  [106978500, 164967731, 200284827, 268334361, 2...
# 2  [187187483, 268334145, 268333371, 265698772, 2...
# 3  [263259777, 253454850, 216192694, 267672018, 2...
# 4  [174420795, 204348049, 130534552, 219709133, 1...

# %%
# from the Twitchly source od
def get_all_follows(user_id: str, show_progress=False):
    """Return a list of all channels a user follows"""
    channels = []

    # We want to avoid adding dupliciate users, which the API has retrieved in the past
    added_channel_names = set()
    offset = 0

    followed_channels = client.users.get_follows(user_id, limit=100)
    while followed_channels:
        for followed_channel in followed_channels:
            offset += 1
            channel = followed_channel.channel

            if channel.display_name not in added_channel_names:
                channels.append(followed_channel.channel) # saves entire json
                added_channel_names.add(channel.display_name)

        followed_channels = client.users.get_follows(user_id, limit=100, offset=offset)
        if show_progress:
            print(offset, end=' ')
    if show_progress:
        print("finished")
    return channels

# %%
followed_channels_by_user = {}
for sample in streamers['Followers Sample']:
    if sample:
        for user_id in sample:
            followed_channels_by_user[user_id] = get_all_follows(user_id) # list of jsons per user (this dict is gonna be massive)

# %%
with open('list_of_channels_followed_by_user.txt', 'w+', encoding='utf-8') as write_file:
    for user_id, followed_channel_list in followed_channels_by_user.items():
        for channel_info in followed_channel_list:
            write_file.write('{}\t{}\n'.format(user_id, channel_info))

# %% [markdown]
# ### Data collection complete, onto analysis
#
# We were able to pick up data for ~18000 users in this go-around.
# Next we will be looking for features in the channel lists that could make the particular channels preferred for the given user.
# Something to note: the channels come in order of most recently followed, so we can rely more heavily on newly followed channels to determine user preference.

# %%
# total number of users sampled
len(followed_channels_by_user)
# Out:
# 18377

# %%
# average number of users sampled (per streamer)
len(followed_channels_by_user) / len(followers)
# Out:
# 183.77

# %%
# average number of followed channels amongst users sampled
np.mean([len(v) for v in followed_channels_by_user.values()])
# Out:
# 43.615116721989445

# %%
user_channels = pd.DataFrame.from_dict(followed_channels_by_user, orient='index')
user_channels.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\twitch\resources.py in __getattr__(self, name)
#      46
#      47     def __getattr__(self, name):
# ---> 48         return self[name]
#      49
#      50     def __delattr__(self, name):
#
# KeyError: '_typ'
# Exception ignored in: 'util.is_period_object'
# Traceback (most recent call last):
#   File "C:\Users\admin\Anaconda3\lib\site-packages\twitch\resources.py", line 48, in __getattr__
#     return self[name]
# KeyError: ('_typ',)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     691                 type_pprinters=self.type_printers,
#     692                 deferred_pprinters=self.deferred_printers)
# --> 693             printer.pretty(obj)
#     694             printer.flush()
#     695             return stream.getvalue()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     378                             if callable(meth):
#     379                                 return meth(obj, self, cycle)
# --> 380             return _default_pprint(obj, self, cycle)
#     381         finally:
#     382             self.end_group()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _default_pprint(obj, p, cycle)
#     493     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     494         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 495         _repr_pprint(obj, p, cycle)
#     496         return
#     497     p.begin_group(1, '<')
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     691     """A pprint that just redirects to the normal repr function."""
#     692     # Find newlines and replace them with p.break_()
# --> 693     output = repr(obj)
#     694     for idx,output_line in enumerate(output.splitlines()):
#     695         if idx:
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __repr__(self)
#      70         Yields Bytestring in Py2, Unicode String in py3.
#      71         """
# ---> 72         return str(self)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __str__(self)
#      49
#      50         if compat.PY3:
# ---> 51             return self.__unicode__()
#      52         return self.__bytes__()
#      53
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __unicode__(self)
#     584             width = None
#     585         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 586                        line_width=width, show_dimensions=show_dimensions)
#     587
#     588         return buf.getvalue()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1527                                            max_cols=max_cols,
#    1528                                            show_dimensions=show_dimensions)
# -> 1529         formatter.to_string()
#    1530
#    1531         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     582         else:
#     583
# --> 584             strcols = self._to_str_columns()
#     585             if self.line_width is None:  # no need to wrap around just print
#     586                 # the whole frame
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     517                 header_colwidth = max(self.col_space or 0,
#     518                                       *(self.adj.len(x) for x in cheader))
# --> 519                 fmt_values = self._format_col(i)
#     520                 fmt_values = _make_fixed_width(fmt_values, self.justify,
#     521                                                minimum=header_colwidth,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     694         return format_array(frame.iloc[:, i]._values, formatter,
#     695                             float_format=self.float_format, na_rep=self.na_rep,
# --> 696                             space=self.col_space, decimal=self.decimal)
#     697
#     698     def to_html(self, classes=None, notebook=False, border=None):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1759                         space=space, justify=justify, decimal=decimal)
#    1760
# -> 1761     return fmt_obj.get_result()
#    1762
#    1763
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1779
#    1780     def get_result(self):
# -> 1781         fmt_values = self._format_strings()
#    1782         return _make_fixed_width(fmt_values, self.justify)
#    1783
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1824                 fmt_values.append(float_format(v))
#    1825             else:
# -> 1826                 fmt_values.append(' %s' % _format(v))
#    1827
#    1828         return fmt_values
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1806             else:
#    1807                 # object dtype
# -> 1808                 return '%s' % formatter(x)
#    1809
#    1810         vals = self.values
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1793         formatter = (
#    1794             self.formatter if self.formatter is not None else
# -> 1795             (lambda x: pprint_thing(x, escape_chars=('\t', '\r', '\n'))))
#    1796
#    1797         def _format(x):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     209         return compat.text_type(result)
#     210
# --> 211     if (compat.PY3 and hasattr(thing, '__next__')) or hasattr(thing, 'next'):
#     212         return compat.text_type(thing)
#     213     elif (isinstance(thing, dict) and
#
# ~\Anaconda3\lib\site-packages\twitch\resources.py in __getattr__(self, name)
#      46
#      47     def __getattr__(self, name):
# ---> 48         return self[name]
#      49
#      50     def __delattr__(self, name):
#
# KeyError: '__next__'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\twitch\resources.py in __getattr__(self, name)
#      46
#      47     def __getattr__(self, name):
# ---> 48         return self[name]
#      49
#      50     def __delattr__(self, name):
#
# KeyError: '_typ'
# Exception ignored in: 'util.is_period_object'
# Traceback (most recent call last):
#   File "C:\Users\admin\Anaconda3\lib\site-packages\twitch\resources.py", line 48, in __getattr__
#     return self[name]
# KeyError: ('_typ',)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     334             method = get_real_method(obj, self.print_method)
#     335             if method is not None:
# --> 336                 return method()
#     337             return None
#     338         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     617
#     618             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 619                                 show_dimensions=show_dimensions, notebook=True)
#     620         else:
#     621             return None
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border)
#    1582                                            decimal=decimal)
#    1583         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 1584         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    1585
#    1586         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     719                                       border=border)
#     720         if hasattr(self.buf, 'write'):
# --> 721             html_renderer.write_result(self.buf)
#     722         elif isinstance(self.buf, compat.string_types):
#     723             with open(self.buf, 'w') as f:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in write_result(self, buf)
#    1164         indent += self.indent_delta
#    1165         indent = self._write_header(indent)
# -> 1166         indent = self._write_body(indent)
#    1167
#    1168         self.write('</table>', indent)
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _write_body(self, indent)
#    1318         fmt_values = {}
#    1319         for i in range(min(len(self.columns), self.max_cols)):
# -> 1320             fmt_values[i] = self.fmt._format_col(i)
#    1321
#    1322         # write values
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     694         return format_array(frame.iloc[:, i]._values, formatter,
#     695                             float_format=self.float_format, na_rep=self.na_rep,
# --> 696                             space=self.col_space, decimal=self.decimal)
#     697
#     698     def to_html(self, classes=None, notebook=False, border=None):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1759                         space=space, justify=justify, decimal=decimal)
#    1760
# -> 1761     return fmt_obj.get_result()
#    1762
#    1763
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1779
#    1780     def get_result(self):
# -> 1781         fmt_values = self._format_strings()
#    1782         return _make_fixed_width(fmt_values, self.justify)
#    1783
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1824                 fmt_values.append(float_format(v))
#    1825             else:
# -> 1826                 fmt_values.append(' %s' % _format(v))
#    1827
#    1828         return fmt_values
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1806             else:
#    1807                 # object dtype
# -> 1808                 return '%s' % formatter(x)
#    1809
#    1810         vals = self.values
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1793         formatter = (
#    1794             self.formatter if self.formatter is not None else
# -> 1795             (lambda x: pprint_thing(x, escape_chars=('\t', '\r', '\n'))))
#    1796
#    1797         def _format(x):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     209         return compat.text_type(result)
#     210
# --> 211     if (compat.PY3 and hasattr(thing, '__next__')) or hasattr(thing, 'next'):
#     212         return compat.text_type(thing)
#     213     elif (isinstance(thing, dict) and
#
# ~\Anaconda3\lib\site-packages\twitch\resources.py in __getattr__(self, name)
#      46
#      47     def __getattr__(self, name):
# ---> 48         return self[name]
#      49
#      50     def __delattr__(self, name):
#
# KeyError: '__next__'
